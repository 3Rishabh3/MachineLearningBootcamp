# %% [markdown]
# # Stackplot

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
myDays = [1, 2, 3, 4, 5]

# %%
organic = [8, 9, 8, 3, 3]
ads = [8, 9, 7, 12, 8]
affiliate = [3, 5, 5, 4, 3]
seller = [9, 5, 8, 9, 14]

# %%
plt.plot([], [], color='#F97F51', label='organic')
plt.plot([], [], color='#1B9CFC', label='ads')
plt.plot([], [], color='#F8EFBA', label='affiliate')
plt.plot([], [], color='#58B19F', label='seller')

plt.stackplot(myDays, organic,ads,affiliate,seller, colors=['#F97F51', '#1B9CFC', '#F8EFBA', '#58B19F'])
plt.xlabel('Number of days')
plt.ylabel('Sales')
plt.legend()

# %% [markdown]
# # Pie charts

# %%
myPieLables = ['Fb', 'Google', 'LinkedIn', 'Pinterest', 'Twitter']

# %%
piecolors = ['#F97F51', '#1B9CFC', '#FD7272', '#58B19F', '#55E6C1']

# %%
plt.pie(ads, labels=myPieLables, colors=piecolors)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc1da00d2d0>,
#   <matplotlib.patches.Wedge at 0x7fc1da1b3010>,
#   <matplotlib.patches.Wedge at 0x7fc1da15de90>,
#   <matplotlib.patches.Wedge at 0x7fc1da1a3190>,
#   <matplotlib.patches.Wedge at 0x7fc1da1a1390>],
#  [Text(0.9253788759906099, 0.5947049149539254, 'Fb'),
#   Text(-0.23382185052875654, 1.0748615456026456, 'Google'),
#   Text(-1.0748615565486352, 0.2338218002108561, 'LinkedIn'),
#   Text(-0.45695648023571767, -1.0005952104475537, 'Pinterest'),
#   Text(0.9253789316708984, -0.5947048283136996, 'Twitter')])
